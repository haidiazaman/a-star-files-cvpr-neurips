# %%
import os

# %%
from pathlib import Path

# %%
from PIL import Image

# %%
img_path = Path('C:/Users/Palaash.HPZ/Desktop/spur neurips/sample dataset/1ffe77b1-199a-415a-8a8e-2aeea18660da/RGB3d045f18-b749-461a-8e49-9ef32a4eb806/rgb_2.png'); assert img.exists()

# %%
img = Image.open(img_path)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512 at 0x2201754C320>

# %%
import numpy as np

# %%
512-273, 512-233
# Out:
# (239, 279)

# %%
"x": 233.0,
              "y": 168.0,
              "width": 40.0,
              "height": 32.0
