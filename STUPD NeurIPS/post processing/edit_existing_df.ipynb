# %%
import pandas as pd

# %% [markdown]
# # existing dynamic 2 objects

# %%
preposition="down"
file=f"{preposition}.csv"
df=pd.read_csv(file)
# df=df.drop(columns='Unnamed: 0')
df["object_1_information"]=df["object_1_information"].apply(lambda x:[x])
# df["object_2_information"]=df["object_2_information"].apply(lambda x:[x])
df["object_1_2d_bounding_boxes"]=df["object_1_2d_bounding_boxes"].apply(lambda x:[x])
# df["object_2_2d_bounding_boxes"]=df["object_2_2d_bounding_boxes"].apply(lambda x:[x])
df["object_1_3d_bounding_boxes"]=df["object_1_3d_bounding_boxes"].apply(lambda x:[x])
# df["object_2_3d_bounding_boxes"]=df["object_2_3d_bounding_boxes"].apply(lambda x:[x])
# df.to_csv(file,index=False)

df["object_2_information"]=pd.Series([],dtype="object")
df["object_2_information"]=df["object_2_information"].apply(lambda x:[])
df["object_2_2d_bounding_boxes"]=pd.Series([],dtype="object")
df["object_2_2d_bounding_boxes"]=df["object_2_2d_bounding_boxes"].apply(lambda x:[])
df["object_2_3d_bounding_boxes"]=pd.Series([],dtype="object")
df["object_2_3d_bounding_boxes"]=df["object_2_3d_bounding_boxes"].apply(lambda x:[])
df=df[['preposition', 'category', 'image_file_name', 'object_1_information','object_2_information','object_1_2d_bounding_boxes','object_2_2d_bounding_boxes', 'object_1_3d_bounding_boxes','object_2_3d_bounding_boxes']]
df.to_csv(file,index=False)

# %%
df.head()
# Out:
#   preposition   category image_file_name  \
# 0        down  furniture       rgb_2.png
# 1        down  furniture       rgb_3.png
# 2        down  furniture       rgb_4.png
# 3        down  furniture       rgb_5.png
# 4        down  furniture       rgb_6.png
#
#                            object_1_information object_2_information  \
# 0  [furniture_sofa_model_normalized_28 Variant]                   []
# 1  [furniture_sofa_model_normalized_28 Variant]                   []
# 2  [furniture_sofa_model_normalized_28 Variant]                   []
# 3  [furniture_sofa_model_normalized_28 Variant]                   []
# 4  [furniture_sofa_model_normalized_28 Variant]                   []
#
#       object_1_2d_bounding_boxes object_2_2d_bounding_boxes  \
# 0  [[55.0, 217.0, 156.0, 181.0]]                         []
# 1  [[56.0, 222.0, 155.0, 185.0]]                         []
# 2  [[56.0, 229.0, 156.0, 189.0]]                         []
# 3  [[56.0, 235.0, 156.0, 192.0]]                         []
# 4  [[57.0, 241.0, 156.0, 197.0]]                         []
#
#                           object_1_3d_bounding_boxes  \
# 0  [{'x': 9.379209, 'y': 4.473857, 'z': 4.56427956}]
# 1  [{'x': 9.379209, 'y': 4.473857, 'z': 4.56427956}]
# 2  [{'x': 9.379209, 'y': 4.473857, 'z': 4.56427956}]
# 3  [{'x': 9.379209, 'y': 4.473857, 'z': 4.56427956}]
# 4  [{'x': 9.379209, 'y': 4.473857, 'z': 4.56427956}]
#
#   object_2_3d_bounding_boxes
# 0                         []
# 1                         []
# 2                         []
# 3                         []
# 4                         []

# %% [markdown]
# # static 2 objects

# %%
import os
import pandas as pd
from tqdm import tqdm

# %%
preposition_name="outside"
root_folder_path="E:/SPUR NEURIPS"
preposition_folder_path=os.path.join(root_folder_path,preposition_name)

#create an empty df
columns=[
    "preposition",
    "category",
    "image_file_name",
    "object_1_information",
    "object_2_information",
    "object_1_2d_bounding_boxes",
    "object_2_2d_bounding_boxes",
    "object_1_3d_bounding_boxes",
    "object_2_3d_bounding_boxes",
]
 
df=pd.DataFrame(columns=columns)

categories=os.listdir(preposition_folder_path)
for category in tqdm(categories):
    category_folder_path=os.path.join(preposition_folder_path,category)
    category_folder_path_list=os.listdir(category_folder_path)
    category_folder_path_list=sorted(category_folder_path_list)
    dataset_folder_path=os.path.join(category_folder_path,category_folder_path_list[0])
    dataset_folder_path_list=os.listdir(dataset_folder_path)
    captures_list=[x for x in dataset_folder_path_list if x.startswith("captures")]
    for captures_json_file in captures_list:
        full_json_path=os.path.join(dataset_folder_path,captures_json_file)
        with open(full_json_path) as file:
            json_data = json.load(file)
            for data in json_data["captures"]:
                filename=data["filename"].split("/")[-1]
                annotations=data["annotations"]
                if annotations[0]["id"]=="bounding box 3D":
                    info_3d=annotations[0]
                    info_2d=annotations[1]
                else:
                    info_3d=annotations[1]
                    info_2d=annotations[0]

                try:
                    object1_info_dict=info_2d["values"][0]
                    object2_info_dict=info_2d["values"][1]
                    object1_info=object1_info_dict["label_name"]
                    object2_info=object2_info_dict["label_name"]

                    object1_bb_2d=[object1_info_dict["x"],object1_info_dict["y"],object1_info_dict["width"],object1_info_dict["height"]]
                    object2_bb_2d=[object2_info_dict["x"],object2_info_dict["y"],object2_info_dict["width"],object2_info_dict["height"]]

                    object1_info_dict=info_3d["values"][0]
                    object2_info_dict=info_3d["values"][1]
                    object1_bb_3d=object1_info_dict["size"]
                    object2_bb_3d=object2_info_dict["size"]
                except:
                    object1_info=[]
                    object2_info=[]
                    object1_bb_2d=[]
                    object2_bb_2d=[]
                    object1_bb_3d=[]
                    object2_bb_3d=[]
#                     print(f"error for {preposition_name}, {category}, {filename}, df index: {len(df)} ")

                new_row={
                    "preposition":preposition_name,
                    "category":category,
                    "image_file_name":filename,
                    "object_1_information":[object1_info],
                    "object_2_information":[object2_info],
                    "object_1_2d_bounding_boxes":[object1_bb_2d],
                    "object_2_2d_bounding_boxes":[object2_bb_2d],
                    "object_1_3d_bounding_boxes":[object1_bb_3d],
                    "object_2_3d_bounding_boxes":[object2_bb_3d],    
                }
                df.loc[len(df)] = new_row

df
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:06<00:00,  1.26s/it]
#      preposition             category image_file_name  \
# 0        outside  furniture container       rgb_2.png
# 1        outside  furniture container       rgb_3.png
# 2        outside  furniture container       rgb_4.png
# 3        outside  furniture container       rgb_5.png
# 4        outside  furniture container       rgb_6.png
# ...          ...                  ...             ...
# 4995     outside   vehicles container     rgb_451.png
# 4996     outside   vehicles container     rgb_452.png
# 4997     outside   vehicles container     rgb_453.png
# 4998     outside   vehicles container     rgb_454.png
# 4999     outside   vehicles container     rgb_455.png
#
#                                    object_1_information  \
# 0          [container_bowl_model_normalized_16 Variant]
# 1       [container_bowl_model_normalized_5 (2) Variant]
# 2         [furniture_stove_model_normalized_18 Variant]
# 3          [furniture_bench_model_normalized_0 Variant]
# 4          [container_bowl_model_normalized_16 Variant]
# ...                                                 ...
# 4995  [vehicles_motorcycle_model_normalized_18 Variant]
# 4996  [container_basket_model_normalized_3 (4) Variant]
# 4997     [container_basket_model_normalized_26 Variant]
# 4998  [vehicles_motorcycle_model_normalized_11 Variant]
# 4999    [container_bowl_model_normalized_5 (2) Variant]
#
#                                    object_2_information  \
# 0           [furniture_sofa_model_normalized_0 Variant]
# 1        [furniture_cabinet_model_normalized_1 Variant]
# 2     [container_basket_model_normalized_28 (5) Vari...
# 3         [container_basket_model_normalized_4 Variant]
# 4           [furniture_sofa_model_normalized_0 Variant]
# ...                                                 ...
# 4995  [container_basket_model_normalized_3 (4) Variant]
# 4996          [vehicles_car_model_normalized_7 Variant]
# 4997          [vehicles_car_model_normalized_9 Variant]
# 4998      [container_basket_model_normalized_4 Variant]
# 4999          [vehicles_car_model_normalized_9 Variant]
#
#          object_1_2d_bounding_boxes      object_2_2d_bounding_boxes  \
# 0      [[263.0, 280.0, 45.0, 44.0]]  [[245.0, 391.0, 108.0, 121.0]]
# 1      [[260.0, 265.0, 48.0, 49.0]]  [[346.0, 225.0, 162.0, 128.0]]
# 2      [[121.0, 194.0, 20.0, 42.0]]    [[220.0, 255.0, 45.0, 44.0]]
# 3     [[273.0, 72.0, 134.0, 103.0]]    [[197.0, 200.0, 47.0, 47.0]]
# 4      [[274.0, 194.0, 40.0, 40.0]]     [[87.0, 149.0, 76.0, 86.0]]
# ...                             ...                             ...
# 4995   [[142.0, 176.0, 26.0, 33.0]]    [[229.0, 266.0, 35.0, 36.0]]
# 4996   [[261.0, 233.0, 38.0, 37.0]]    [[108.0, 245.0, 51.0, 34.0]]
# 4997   [[233.0, 277.0, 35.0, 36.0]]    [[288.0, 393.0, 34.0, 74.0]]
# 4998    [[259.0, 95.0, 19.0, 41.0]]    [[231.0, 215.0, 38.0, 37.0]]
# 4999   [[232.0, 270.0, 29.0, 29.0]]    [[133.0, 236.0, 26.0, 64.0]]
#
#                              object_1_3d_bounding_boxes  \
# 0     [{'x': 1.92512345, 'y': 0.336845875, 'z': 1.92...
# 1     [{'x': 2.00518036, 'y': 0.8329382, 'z': 2.0051...
# 2     [{'x': 1.65136218, 'y': 0.4954096, 'z': 1.7476...
# 3     [{'x': 6.43487024, 'y': 2.796646, 'z': 2.01485...
# 4     [{'x': 1.88375413, 'y': 0.329607338, 'z': 1.88...
# ...                                                 ...
# 4995  [{'x': 0.42573452, 'y': 1.19992363, 'z': 2.030...
# 4996  [{'x': 1.82269812, 'y': 1.784457, 'z': 1.82269...
# 4997  [{'x': 2.0885334, 'y': 1.91448891, 'z': 2.0885...
# 4998  [{'x': 1.18442738, 'y': 1.21421647, 'z': 2.402...
# 4999  [{'x': 1.66356516, 'y': 0.6910337, 'z': 1.6635...
#
#                              object_2_3d_bounding_boxes
# 0     [{'x': 4.63384151, 'y': 3.248954, 'z': 3.17892...
# 1     [{'x': 3.769091, 'y': 5.6536355, 'z': 2.061508...
# 2     [{'x': 1.96733248, 'y': 2.29277635, 'z': 1.967...
# 3     [{'x': 2.31886053, 'y': 2.08615112, 'z': 2.318...
# 4     [{'x': 4.57787561, 'y': 3.20971513, 'z': 3.140...
# ...                                                 ...
# 4995  [{'x': 2.0033567, 'y': 1.96132469, 'z': 2.0033...
# 4996  [{'x': 1.1766609, 'y': 0.7884536, 'z': 2.68218...
# 4997  [{'x': 1.55422091, 'y': 1.14926946, 'z': 3.715...
# 4998  [{'x': 2.21520853, 'y': 1.99290121, 'z': 2.215...
# 4999  [{'x': 1.50462067, 'y': 1.11259258, 'z': 3.597...
#
# [5000 rows x 9 columns]

# %%
file=f"{preposition_name}.csv"
df.to_csv(file,index=False)

# %% [markdown]
# # create static multiple objects

# %%
preposition_name="among"
root_folder_path="E:/SPUR NEURIPS"
preposition_folder_path=os.path.join(root_folder_path,preposition_name)

#create an empty df
columns=[
    "preposition",
    "category",
    "image_file_name",
    "object_1_information",
    "object_2_information",
    "object_1_2d_bounding_boxes",
    "object_2_2d_bounding_boxes",
    "object_1_3d_bounding_boxes",
    "object_2_3d_bounding_boxes",
]
 
df=pd.DataFrame(columns=columns)

categories=os.listdir(preposition_folder_path)
for category in tqdm(categories):
    category_folder_path=os.path.join(preposition_folder_path,category)
    category_folder_path_list=os.listdir(category_folder_path)
    category_folder_path_list=sorted(category_folder_path_list)
    dataset_folder_path=os.path.join(category_folder_path,category_folder_path_list[0])
    dataset_folder_path_list=os.listdir(dataset_folder_path)
    captures_list=[x for x in dataset_folder_path_list if x.startswith("captures")]
    for captures_json_file in captures_list:
        full_json_path=os.path.join(dataset_folder_path,captures_json_file)
        with open(full_json_path) as file:
            json_data = json.load(file)
            for data in json_data["captures"]:
                filename=data["filename"].split("/")[-1]
                annotations=data["annotations"]
                if annotations[0]["id"]=="bounding box 3D":
                    info_3d=annotations[0]
                    info_2d=annotations[1]
                else:
                    info_3d=annotations[1]
                    info_2d=annotations[0]
                break
        break
    break
#                 try:
#                     object1_info_dict=info_2d["values"][0]
#                     object2_info_dict=info_2d["values"][1]
#                     object1_info=object1_info_dict["label_name"]
#                     object2_info=object2_info_dict["label_name"]

#                     object1_bb_2d=[object1_info_dict["x"],object1_info_dict["y"],object1_info_dict["width"],object1_info_dict["height"]]
#                     object2_bb_2d=[object2_info_dict["x"],object2_info_dict["y"],object2_info_dict["width"],object2_info_dict["height"]]

#                     object1_info_dict=info_3d["values"][0]
#                     object2_info_dict=info_3d["values"][1]
#                     object1_bb_3d=object1_info_dict["size"]
#                     object2_bb_3d=object2_info_dict["size"]
#                 except:
#                     object1_info=""
#                     object2_info=""
#                     object1_bb_2d=[]
#                     object2_bb_2d=[]
#                     object1_bb_3d=[]
#                     object2_bb_3d=[]
# #                     print(f"error for {preposition_name}, {category}, {filename}, df index: {len(df)} ")

#                 new_row={
#                     "preposition":preposition_name,
#                     "category":category,
#                     "image_file_name":filename,
#                     "object_1_information":object1_info,
#                     "object_2_information":object2_info,
#                     "object_1_2d_bounding_boxes":object1_bb_2d,
#                     "object_2_2d_bounding_boxes":object2_bb_2d,
#                     "object_1_3d_bounding_boxes":object1_bb_3d,
#                     "object_2_3d_bounding_boxes":object2_bb_3d,    
#                 }
#                 df.loc[len(df)] = new_row

# df
# Out:
#   0%|                                                                                           | 0/11 [00:00<?, ?it/s]

# %%
info_2d
# Out:
# {'id': 'bounding box',
#  'annotation_definition': 'bounding box',
#  'values': [{'label_id': 36,
#    'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#    'instance_id': 7,
#    'x': 300.0,
#    'y': 94.0,
#    'width': 62.0,
#    'height': 84.0},
#   {'label_id': 36,
#    'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#    'instance_id': 8,
#    'x': 253.0,
#    'y': 215.0,
#    'width': 117.0,
#    'height': 35.0},
#   {'label_id': 36,
#    'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#    'instance_id': 5,
#    'x': 376.0,
#    'y': 229.0,
#    'width': 51.0,
#    'height': 50.0},
#   {'label_id': 29,
#    'label_name': 'furniture_bench_model_normalized_26 Variant',
#    'instance_id': 1,
#    'x': 340.0,
#    'y': 283.0,
#    'width': 13.0,
#    'height': 3.0},
#   {'label_id': 36,
#    'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#    'instance_id': 4,
#    'x': 342.0,
#    'y': 276.0,
#    'width': 8.0,
#    'height': 12.0},
#   {'label_id': 36,
#    'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#    'instance_id': 10,
#    'x': 277.0,
#    'y': 214.0,
#    'width': 81.0,
#    'height': 120.0},
#   {'label_id': 36,
#    'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#    'instance_id': 6,
#    'x': 381.0,
#    'y': 269.0,
#    'width': 73.0,
#    'height': 71.0},
#   {'label_id': 29,
#    'label_name': 'furniture_bench_model_normalized_26 Variant',
#    'instance_id': 2,
#    'x': 494.0,
#    'y': 334.0,
#    'width': 18.0,
#    'height': 53.0},
#   {'label_id': 29,
#    'label_name': 'furniture_bench_model_normalized_26 Variant',
#    'instance_id': 3,
#    'x': 276.0,
#    'y': 377.0,
#    'width': 143.0,
#    'height': 64.0},
#   {'label_id': 36,
#    'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#    'instance_id': 9,
#    'x': 406.0,
#    'y': 367.0,
#    'width': 50.0,
#    'height': 116.0}]}

# %%
object1_info_dict=info_2d["values"]
object1_info_dict
# Out:
# [{'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 7,
#   'x': 300.0,
#   'y': 94.0,
#   'width': 62.0,
#   'height': 84.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 8,
#   'x': 253.0,
#   'y': 215.0,
#   'width': 117.0,
#   'height': 35.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 5,
#   'x': 376.0,
#   'y': 229.0,
#   'width': 51.0,
#   'height': 50.0},
#  {'label_id': 29,
#   'label_name': 'furniture_bench_model_normalized_26 Variant',
#   'instance_id': 1,
#   'x': 340.0,
#   'y': 283.0,
#   'width': 13.0,
#   'height': 3.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 4,
#   'x': 342.0,
#   'y': 276.0,
#   'width': 8.0,
#   'height': 12.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 10,
#   'x': 277.0,
#   'y': 214.0,
#   'width': 81.0,
#   'height': 120.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 6,
#   'x': 381.0,
#   'y': 269.0,
#   'width': 73.0,
#   'height': 71.0},
#  {'label_id': 29,
#   'label_name': 'furniture_bench_model_normalized_26 Variant',
#   'instance_id': 2,
#   'x': 494.0,
#   'y': 334.0,
#   'width': 18.0,
#   'height': 53.0},
#  {'label_id': 29,
#   'label_name': 'furniture_bench_model_normalized_26 Variant',
#   'instance_id': 3,
#   'x': 276.0,
#   'y': 377.0,
#   'width': 143.0,
#   'height': 64.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 9,
#   'x': 406.0,
#   'y': 367.0,
#   'width': 50.0,
#   'height': 116.0}]

# %%
sorted_data = sorted(object1_info_dict, key=lambda x: x['instance_id'])
sorted_data
# Out:
# [{'label_id': 29,
#   'label_name': 'furniture_bench_model_normalized_26 Variant',
#   'instance_id': 1,
#   'x': 340.0,
#   'y': 283.0,
#   'width': 13.0,
#   'height': 3.0},
#  {'label_id': 29,
#   'label_name': 'furniture_bench_model_normalized_26 Variant',
#   'instance_id': 2,
#   'x': 494.0,
#   'y': 334.0,
#   'width': 18.0,
#   'height': 53.0},
#  {'label_id': 29,
#   'label_name': 'furniture_bench_model_normalized_26 Variant',
#   'instance_id': 3,
#   'x': 276.0,
#   'y': 377.0,
#   'width': 143.0,
#   'height': 64.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 4,
#   'x': 342.0,
#   'y': 276.0,
#   'width': 8.0,
#   'height': 12.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 5,
#   'x': 376.0,
#   'y': 229.0,
#   'width': 51.0,
#   'height': 50.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 6,
#   'x': 381.0,
#   'y': 269.0,
#   'width': 73.0,
#   'height': 71.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 7,
#   'x': 300.0,
#   'y': 94.0,
#   'width': 62.0,
#   'height': 84.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 8,
#   'x': 253.0,
#   'y': 215.0,
#   'width': 117.0,
#   'height': 35.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 9,
#   'x': 406.0,
#   'y': 367.0,
#   'width': 50.0,
#   'height': 116.0},
#  {'label_id': 36,
#   'label_name': 'furniture_cabinet_model_normalized_23 Variant',
#   'instance_id': 10,
#   'x': 277.0,
#   'y': 214.0,
#   'width': 81.0,
#   'height': 120.0}]
