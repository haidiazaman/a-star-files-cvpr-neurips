# %%
import json
import os
import pandas as pd
from tqdm import tqdm
from pprint import pprint

# %% [markdown]
# info needed
# -preposition
# -category
# -image file name
# -object 1 info
# -object 2 info
# -object 1 2d bb coordinates, xtopleft,y topright, width, height
# -object 2 2d bb coordinates, xtopleft,y topright, width, height
# -object 1 3d bb
# -object 2 3d bb

# %% [markdown]
# # 2 objects only
# -check by instance id

# %%
import os
import json
import pandas as pd
from tqdm import tqdm

preposition_name="around"
root_folder_path="E:/SPUR NEURIPS"
preposition_folder_path=os.path.join(root_folder_path,preposition_name)

#create an empty df
columns=[
    "preposition",
    "category",
    "image_file_name",
    "object_1_information",
    "object_2_information",
    "object_1_2d_bounding_boxes",
    "object_2_2d_bounding_boxes",
    "object_1_3d_bounding_boxes",
    "object_2_3d_bounding_boxes",
]
 
df=pd.DataFrame(columns=columns)

categories=os.listdir(preposition_folder_path)
for category in tqdm(categories):
    category_folder_path=os.path.join(preposition_folder_path,category)
    category_folder_path_list=os.listdir(category_folder_path)
    category_folder_path_list=sorted(category_folder_path_list)
    dataset_folder_path=os.path.join(category_folder_path,category_folder_path_list[0])
    dataset_folder_path_list=os.listdir(dataset_folder_path)
    captures_list=[x for x in dataset_folder_path_list if x.startswith("captures")]
    for captures_json_file in captures_list:
        full_json_path=os.path.join(dataset_folder_path,captures_json_file)
        with open(full_json_path) as file:
            json_data = json.load(file)
            for data in json_data["captures"]:
                filename=data["filename"].split("/")[-1]
                annotations=data["annotations"]
                if annotations[0]["id"]=="bounding box 3D":
                    info_3d=annotations[0]
                    info_2d=annotations[1]
                else:
                    info_3d=annotations[1]
                    info_2d=annotations[0]
                    
                try:
                    object_info_dict=info_2d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    object1_info=[sorted_data[0]["label_name"]]
                    object2_info=[sorted_data[1]["label_name"]]
                    object1_bb_2d=[[sorted_data[0]["x"],sorted_data[0]["y"],sorted_data[0]["width"],sorted_data[0]["height"]]]
                    object2_bb_2d=[[sorted_data[1]["x"],sorted_data[1]["y"],sorted_data[1]["width"],sorted_data[1]["height"]]]

                    object_info_dict=info_3d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    object1_bb_3d=[sorted_data[0]["size"]]
                    object2_bb_3d=[sorted_data[1]["size"]]  
                except:
                    object1_info=[]
                    object2_info=[]
                    object1_bb_2d=[]
                    object2_bb_2d=[]
                    object1_bb_3d=[]
                    object2_bb_3d=[]
#                     print(f"error for {preposition_name}, {category}, {filename}, df index: {len(df)} ")

                new_row={
                    "preposition":preposition_name,
                    "category":category,
                    "image_file_name":filename,
                    "object_1_information":object1_info,
                    "object_2_information":object2_info,
                    "object_1_2d_bounding_boxes":object1_bb_2d,
                    "object_2_2d_bounding_boxes":object2_bb_2d,
                    "object_1_3d_bounding_boxes":object1_bb_3d,
                    "object_2_3d_bounding_boxes":object2_bb_3d,    
                }
    
                df.loc[len(df)] = new_row
        
        
print(preposition_name)
print(len(df))
df.tail()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [1:02:43<00:00, 342.13s/it]
# around
# 150000
#        preposition           category image_file_name  \
# 149995      around  building building    rgb_2547.png
# 149996      around  building building    rgb_2548.png
# 149997      around  building building    rgb_2549.png
# 149998      around  building building    rgb_2550.png
# 149999      around  building building    rgb_2551.png
#
#                                      object_1_information  \
# 149995  [grounded_large_objects_train_model_normalized...
# 149996  [grounded_large_objects_train_model_normalized...
# 149997  [grounded_large_objects_train_model_normalized...
# 149998  [grounded_large_objects_train_model_normalized...
# 149999  [grounded_large_objects_train_model_normalized...
#
#                                      object_2_information  \
# 149995  [grounded_large_objects_vessel_model_normalize...
# 149996  [grounded_large_objects_vessel_model_normalize...
# 149997  [grounded_large_objects_vessel_model_normalize...
# 149998  [grounded_large_objects_vessel_model_normalize...
# 149999  [grounded_large_objects_vessel_model_normalize...
#
#             object_1_2d_bounding_boxes    object_2_2d_bounding_boxes  \
# 149995  [[384.0, 352.0, 126.0, 160.0]]  [[283.0, 233.0, 31.0, 68.0]]
# 149996   [[327.0, 386.0, 61.0, 126.0]]  [[283.0, 233.0, 31.0, 68.0]]
# 149997   [[251.0, 387.0, 34.0, 125.0]]  [[283.0, 233.0, 31.0, 68.0]]
# 149998   [[229.0, 383.0, 41.0, 129.0]]  [[283.0, 233.0, 31.0, 68.0]]
# 149999   [[132.0, 348.0, 85.0, 164.0]]  [[283.0, 233.0, 31.0, 68.0]]
#
#                                object_1_3d_bounding_boxes  \
# 149995  [{'x': 5.081271, 'y': 7.585633, 'z': 32.3702126}]
# 149996  [{'x': 5.081271, 'y': 7.585633, 'z': 32.3702126}]
# 149997  [{'x': 5.081271, 'y': 7.585633, 'z': 32.3702126}]
# 149998  [{'x': 5.081271, 'y': 7.585633, 'z': 32.3702126}]
# 149999  [{'x': 5.081271, 'y': 7.585633, 'z': 32.3702126}]
#
#                                object_2_3d_bounding_boxes
# 149995  [{'x': 4.677506, 'y': 11.5403118, 'z': 9.319736}]
# 149996  [{'x': 4.677506, 'y': 11.5403118, 'z': 9.319736}]
# 149997  [{'x': 4.677506, 'y': 11.5403118, 'z': 9.319736}]
# 149998  [{'x': 4.677506, 'y': 11.5403118, 'z': 9.319736}]
# 149999  [{'x': 4.677506, 'y': 11.5403118, 'z': 9.319736}]

# %%
file=f"{preposition_name}.csv"
print(file)
df.to_csv(file,index=False)
# Out:
# around.csv

# %% [markdown]
# # 1 object only
# -check by instance id
# -only for all over, down, up

# %%
import os
import json
import pandas as pd
from tqdm import tqdm

preposition_name="down"
root_folder_path="E:/SPUR NEURIPS"
preposition_folder_path=os.path.join(root_folder_path,preposition_name)

#create an empty df
columns=[
    "preposition",
    "category",
    "image_file_name",
    "object_1_information",
    "object_2_information",
    "object_1_2d_bounding_boxes",
    "object_2_2d_bounding_boxes",
    "object_1_3d_bounding_boxes",
    "object_2_3d_bounding_boxes",
]
 
df=pd.DataFrame(columns=columns)

categories=os.listdir(preposition_folder_path)
for category in tqdm(categories):
    category_folder_path=os.path.join(preposition_folder_path,category)
    category_folder_path_list=os.listdir(category_folder_path)
    category_folder_path_list=sorted(category_folder_path_list)
    dataset_folder_path=os.path.join(category_folder_path,category_folder_path_list[0])
    dataset_folder_path_list=os.listdir(dataset_folder_path)
    captures_list=[x for x in dataset_folder_path_list if x.startswith("captures")]
    for captures_json_file in captures_list:
        full_json_path=os.path.join(dataset_folder_path,captures_json_file)
        with open(full_json_path) as file:
            json_data = json.load(file)
            for data in json_data["captures"]:
                filename=data["filename"].split("/")[-1]
                annotations=data["annotations"]
                if annotations[0]["id"]=="bounding box 3D":
                    info_3d=annotations[0]
                    info_2d=annotations[1]
                else:
                    info_3d=annotations[1]
                    info_2d=annotations[0]
                    
                try:
                    object_info_dict=info_2d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    object1_info=[x["label_name"] for x in sorted_data]
                    object2_info=[]
                    object1_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in sorted_data]
                    object2_bb_2d=[]

                    object_info_dict=info_3d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    object1_bb_3d=[x["size"] for x in sorted_data]
                    object2_bb_3d=[]  
                except:
                    object1_info=[]
                    object2_info=[]
                    object1_bb_2d=[]
                    object2_bb_2d=[]
                    object1_bb_3d=[]
                    object2_bb_3d=[]
#                     print(f"error for {preposition_name}, {category}, {filename}, df index: {len(df)} ")

                new_row={
                    "preposition":preposition_name,
                    "category":category,
                    "image_file_name":filename,
                    "object_1_information":object1_info,
                    "object_2_information":object2_info,
                    "object_1_2d_bounding_boxes":object1_bb_2d,
                    "object_2_2d_bounding_boxes":object2_bb_2d,
                    "object_1_3d_bounding_boxes":object1_bb_3d,
                    "object_2_3d_bounding_boxes":object2_bb_3d,    
                }
    
                df.loc[len(df)] = new_row
        
        
print(preposition_name)
print(len(df))
df.tail()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [32:04<00:00, 384.84s/it]
# down
# 150000
#        preposition  category image_file_name  \
# 149995        down  vehicles   rgb_13617.png
# 149996        down  vehicles   rgb_13618.png
# 149997        down  vehicles   rgb_13619.png
# 149998        down  vehicles   rgb_13620.png
# 149999        down  vehicles   rgb_13621.png
#
#                                      object_1_information  \
# 149995  [vehicles_motorcycle_model_normalized_11 Variant]
# 149996  [vehicles_motorcycle_model_normalized_11 Variant]
# 149997  [vehicles_motorcycle_model_normalized_11 Variant]
# 149998  [vehicles_motorcycle_model_normalized_11 Variant]
# 149999  [vehicles_motorcycle_model_normalized_11 Variant]
#
#        object_2_information     object_1_2d_bounding_boxes  \
# 149995                   []  [[128.0, 322.0, 109.0, 63.0]]
# 149996                   []  [[128.0, 326.0, 109.0, 63.0]]
# 149997                   []  [[127.0, 332.0, 109.0, 64.0]]
# 149998                   []  [[127.0, 337.0, 108.0, 63.0]]
# 149999                   []  [[126.0, 342.0, 109.0, 64.0]]
#
#        object_2_2d_bounding_boxes  \
# 149995                         []
# 149996                         []
# 149997                         []
# 149998                         []
# 149999                         []
#
#                               object_1_3d_bounding_boxes  \
# 149995  [{'x': 3.44854832, 'y': 3.535281, 'z': 6.99509}]
# 149996  [{'x': 3.44854832, 'y': 3.535281, 'z': 6.99509}]
# 149997  [{'x': 3.44854832, 'y': 3.535281, 'z': 6.99509}]
# 149998  [{'x': 3.44854832, 'y': 3.535281, 'z': 6.99509}]
# 149999  [{'x': 3.44854832, 'y': 3.535281, 'z': 6.99509}]
#
#        object_2_3d_bounding_boxes
# 149995                         []
# 149996                         []
# 149997                         []
# 149998                         []
# 149999                         []

# %%
file=f"{preposition_name}.csv"
print(file)
df.to_csv(file,index=False)
# Out:
# down.csv

# %% [markdown]
# # multiple object 1, 1 object 2
# -set the last instance id object as object 2, the rest as object 1
# -only for along position, around static

# %%
import os
import pandas as pd
from tqdm import tqdm

preposition_name="along position"
root_folder_path="E:/SPUR NEURIPS"
preposition_folder_path=os.path.join(root_folder_path,preposition_name)

#create an empty df
columns=[
    "preposition",
    "category",
    "image_file_name",
    "object_1_information",
    "object_2_information",
    "object_1_2d_bounding_boxes",
    "object_2_2d_bounding_boxes",
    "object_1_3d_bounding_boxes",
    "object_2_3d_bounding_boxes",
]
 
df=pd.DataFrame(columns=columns)

categories=os.listdir(preposition_folder_path)
for category in tqdm(categories):
    category_folder_path=os.path.join(preposition_folder_path,category)
    category_folder_path_list=os.listdir(category_folder_path)
    category_folder_path_list=sorted(category_folder_path_list)
    dataset_folder_path=os.path.join(category_folder_path,category_folder_path_list[0])
    dataset_folder_path_list=os.listdir(dataset_folder_path)
    captures_list=[x for x in dataset_folder_path_list if x.startswith("captures")]
    for captures_json_file in captures_list:
        full_json_path=os.path.join(dataset_folder_path,captures_json_file)
        with open(full_json_path) as file:
            json_data = json.load(file)
            for data in json_data["captures"]:
                filename=data["filename"].split("/")[-1]
                annotations=data["annotations"]
                if annotations[0]["id"]=="bounding box 3D":
                    info_3d=annotations[0]
                    info_2d=annotations[1]
                else:
                    info_3d=annotations[1]
                    info_2d=annotations[0]
                    
                try:
                    object_info_dict=info_2d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    list1 = [sorted_data[:-1]]
                    list2 = [sorted_data[-1]]                    
                    object1_info=[x["label_name"] for x in list1]
                    object2_info=[x["label_name"] for x in list2]
                    object1_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in list1]
                    object2_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in list2]

                    object_info_dict=info_3d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    list1 = [sorted_data[:-1]]
                    list2 = [sorted_data[-1]]  
                    object1_bb_3d=[x["size"] for x in list1]
                    object2_bb_3d=[x["size"] for x in list2]
                    
                except:
                    object1_info=[]
                    object2_info=[]
                    object1_bb_2d=[]
                    object2_bb_2d=[]
                    object1_bb_3d=[]
                    object2_bb_3d=[]
#                     print(f"error for {preposition_name}, {category}, {filename}, df index: {len(df)} ")

                new_row={
                    "preposition":preposition_name,
                    "category":category,
                    "image_file_name":filename,
                    "object_1_information":object1_info,
                    "object_2_information":object2_info,
                    "object_1_2d_bounding_boxes":object1_bb_2d,
                    "object_2_2d_bounding_boxes":object2_bb_2d,
                    "object_1_3d_bounding_boxes":object1_bb_3d,
                    "object_2_3d_bounding_boxes":object2_bb_3d,    
                }
                df.loc[len(df)] = new_row
        
        
print(preposition_name)
print(len(df))
df.tail()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:06<00:00,  2.16it/s]
# below
# 5000
#      preposition           category image_file_name  \
# 4995       below  vehicles vehicles      rgb_49.png
# 4996       below  vehicles vehicles      rgb_50.png
# 4997       below  vehicles vehicles      rgb_51.png
# 4998       below  vehicles vehicles      rgb_52.png
# 4999       below  vehicles vehicles      rgb_53.png
#
#                                    object_1_information  \
# 4995  [vehicles_motorcycle_model_normalized_26 Variant]
# 4996         [vehicles_bus_model_normalized_29 Variant]
# 4997  [vehicles_bus_model_normalized_29 Variant, veh...
# 4998   [vehicles_motorcycle_model_normalized_9 Variant]
# 4999          [vehicles_car_model_normalized_7 Variant]
#
#                                    object_2_information  \
# 4995  [vehicles_motorcycle_model_normalized_18 Variant]
# 4996         [vehicles_bus_model_normalized_22 Variant]
# 4997                                                 []
# 4998  [vehicles_motorcycle_model_normalized_21 Variant]
# 4999  [vehicles_motorcycle_model_normalized_26 Variant]
#
#                              object_1_2d_bounding_boxes  \
# 4995                       [[210.0, 365.0, 46.0, 89.0]]
# 4996                      [[41.0, 247.0, 431.0, 265.0]]
# 4997  [[123.0, 235.0, 389.0, 222.0], [218.0, 0.0, 29...
# 4998                       [[253.0, 278.0, 61.0, 46.0]]
# 4999                     [[155.0, 408.0, 123.0, 104.0]]
#
#           object_2_2d_bounding_boxes  \
# 4995    [[130.0, 73.0, 131.0, 96.0]]
# 4996  [[132.0, 108.0, 380.0, 127.0]]
# 4997                              []
# 4998     [[200.0, 52.0, 99.0, 88.0]]
# 4999   [[104.0, 189.0, 122.0, 55.0]]
#
#                              object_1_3d_bounding_boxes  \
# 4995  [[{'x': 3.68977356, 'y': 4.10723257, 'z': 13.9...
# 4996  [[{'x': 10.6660748, 'y': 11.8382, 'z': 40.5224...
# 4997  [[{'x': 10.7983313, 'y': 11.9849939, 'z': 41.0...
# 4998  [[{'x': 4.42329741, 'y': 4.50555849, 'z': 12.0...
# 4999  [[{'x': 8.064554, 'y': 5.40387154, 'z': 18.383...
#
#                              object_2_3d_bounding_boxes
# 4995  [[{'x': 2.55518985, 'y': 7.20174551, 'z': 12.1...
# 4996  [[{'x': 9.244875, 'y': 8.296465, 'z': 37.90234}]]
# 4997                                                 []
# 4998  [[{'x': 3.41124964, 'y': 5.57235861, 'z': 11.4...
# 4999  [[{'x': 3.185494, 'y': 3.54589963, 'z': 12.011...

# %%
file=f"{preposition_name}.csv"
print(file)
df.to_csv(file,index=False)
# Out:
# above.csv

# %% [markdown]
# # 1 object 1, multiple object 2
# -set the first instance id object as object 1, the rest as object 2
# -only for between

# %%
import os
import pandas as pd
from tqdm import tqdm

preposition_name="between"
root_folder_path="E:/SPUR NEURIPS"
preposition_folder_path=os.path.join(root_folder_path,preposition_name)

#create an empty df
columns=[
    "preposition",
    "category",
    "image_file_name",
    "object_1_information",
    "object_2_information",
    "object_1_2d_bounding_boxes",
    "object_2_2d_bounding_boxes",
    "object_1_3d_bounding_boxes",
    "object_2_3d_bounding_boxes",
]
 
df=pd.DataFrame(columns=columns)

categories=os.listdir(preposition_folder_path)
for category in tqdm(categories):
    category_folder_path=os.path.join(preposition_folder_path,category)
    category_folder_path_list=os.listdir(category_folder_path)
    category_folder_path_list=sorted(category_folder_path_list)
    dataset_folder_path=os.path.join(category_folder_path,category_folder_path_list[0])
    dataset_folder_path_list=os.listdir(dataset_folder_path)
    captures_list=[x for x in dataset_folder_path_list if x.startswith("captures")]
    for captures_json_file in captures_list:
        full_json_path=os.path.join(dataset_folder_path,captures_json_file)
        with open(full_json_path) as file:
            json_data = json.load(file)
            for data in json_data["captures"]:
                filename=data["filename"].split("/")[-1]
                annotations=data["annotations"]
                if annotations[0]["id"]=="bounding box 3D":
                    info_3d=annotations[0]
                    info_2d=annotations[1]
                else:
                    info_3d=annotations[1]
                    info_2d=annotations[0]
                    
                try:
                    object_info_dict=info_2d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    list1 = [sorted_data[0]]
                    list2 = [sorted_data[1:]]                    
                    object1_info=[x["label_name"] for x in list1]
                    object2_info=[x["label_name"] for x in list2]
                    object1_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in list1]
                    object2_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in list2]

                    object_info_dict=info_3d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    list1 = [sorted_data[0]]
                    list2 = [sorted_data[1:]]  
                    object1_bb_3d=[x["size"] for x in list1]
                    object2_bb_3d=[x["size"] for x in list2]
                    
                except:
                    object1_info=[]
                    object2_info=[]
                    object1_bb_2d=[]
                    object2_bb_2d=[]
                    object1_bb_3d=[]
                    object2_bb_3d=[]
#                     print(f"error for {preposition_name}, {category}, {filename}, df index: {len(df)} ")

                new_row={
                    "preposition":preposition_name,
                    "category":category,
                    "image_file_name":filename,
                    "object_1_information":object1_info,
                    "object_2_information":object2_info,
                    "object_1_2d_bounding_boxes":object1_bb_2d,
                    "object_2_2d_bounding_boxes":object2_bb_2d,
                    "object_1_3d_bounding_boxes":object1_bb_3d,
                    "object_2_3d_bounding_boxes":object2_bb_3d,    
                }
                df.loc[len(df)] = new_row
        
        
print(preposition_name)
print(len(df))
df.tail()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:06<00:00,  2.16it/s]
# below
# 5000
#      preposition           category image_file_name  \
# 4995       below  vehicles vehicles      rgb_49.png
# 4996       below  vehicles vehicles      rgb_50.png
# 4997       below  vehicles vehicles      rgb_51.png
# 4998       below  vehicles vehicles      rgb_52.png
# 4999       below  vehicles vehicles      rgb_53.png
#
#                                    object_1_information  \
# 4995  [vehicles_motorcycle_model_normalized_26 Variant]
# 4996         [vehicles_bus_model_normalized_29 Variant]
# 4997  [vehicles_bus_model_normalized_29 Variant, veh...
# 4998   [vehicles_motorcycle_model_normalized_9 Variant]
# 4999          [vehicles_car_model_normalized_7 Variant]
#
#                                    object_2_information  \
# 4995  [vehicles_motorcycle_model_normalized_18 Variant]
# 4996         [vehicles_bus_model_normalized_22 Variant]
# 4997                                                 []
# 4998  [vehicles_motorcycle_model_normalized_21 Variant]
# 4999  [vehicles_motorcycle_model_normalized_26 Variant]
#
#                              object_1_2d_bounding_boxes  \
# 4995                       [[210.0, 365.0, 46.0, 89.0]]
# 4996                      [[41.0, 247.0, 431.0, 265.0]]
# 4997  [[123.0, 235.0, 389.0, 222.0], [218.0, 0.0, 29...
# 4998                       [[253.0, 278.0, 61.0, 46.0]]
# 4999                     [[155.0, 408.0, 123.0, 104.0]]
#
#           object_2_2d_bounding_boxes  \
# 4995    [[130.0, 73.0, 131.0, 96.0]]
# 4996  [[132.0, 108.0, 380.0, 127.0]]
# 4997                              []
# 4998     [[200.0, 52.0, 99.0, 88.0]]
# 4999   [[104.0, 189.0, 122.0, 55.0]]
#
#                              object_1_3d_bounding_boxes  \
# 4995  [[{'x': 3.68977356, 'y': 4.10723257, 'z': 13.9...
# 4996  [[{'x': 10.6660748, 'y': 11.8382, 'z': 40.5224...
# 4997  [[{'x': 10.7983313, 'y': 11.9849939, 'z': 41.0...
# 4998  [[{'x': 4.42329741, 'y': 4.50555849, 'z': 12.0...
# 4999  [[{'x': 8.064554, 'y': 5.40387154, 'z': 18.383...
#
#                              object_2_3d_bounding_boxes
# 4995  [[{'x': 2.55518985, 'y': 7.20174551, 'z': 12.1...
# 4996  [[{'x': 9.244875, 'y': 8.296465, 'z': 37.90234}]]
# 4997                                                 []
# 4998  [[{'x': 3.41124964, 'y': 5.57235861, 'z': 11.4...
# 4999  [[{'x': 3.185494, 'y': 3.54589963, 'z': 12.011...

# %%
file=f"{preposition_name}.csv"
print(file)
df.to_csv(file,index=False)
# Out:
# above.csv

# %% [markdown]
# # multiple object 1, multiple object 2
# 1. check if there are 1 or 2 object types (for among, you can have object 1 and 2 be of the same types)
# a. 2 object types
# -use current logic of splitting sorted_data into list 1 and 2 based on label_id
# b. 1 object type
# -set list 1 to be first object, the rest as object 2 \into list 2
# -only for among

# %%
import os
import pandas as pd
from tqdm import tqdm

preposition_name="among"
root_folder_path="E:/SPUR NEURIPS"
preposition_folder_path=os.path.join(root_folder_path,preposition_name)

#create an empty df
columns=[
    "preposition",
    "category",
    "image_file_name",
    "object_1_information",
    "object_2_information",
    "object_1_2d_bounding_boxes",
    "object_2_2d_bounding_boxes",
    "object_1_3d_bounding_boxes",
    "object_2_3d_bounding_boxes",
]
 
df=pd.DataFrame(columns=columns)

categories=os.listdir(preposition_folder_path)
for category in tqdm(categories):
    category_folder_path=os.path.join(preposition_folder_path,category)
    category_folder_path_list=os.listdir(category_folder_path)
    category_folder_path_list=sorted(category_folder_path_list)
    dataset_folder_path=os.path.join(category_folder_path,category_folder_path_list[0])
    dataset_folder_path_list=os.listdir(dataset_folder_path)
    captures_list=[x for x in dataset_folder_path_list if x.startswith("captures")]
    for captures_json_file in captures_list:
        full_json_path=os.path.join(dataset_folder_path,captures_json_file)
        with open(full_json_path) as file:
            json_data = json.load(file)
            for data in json_data["captures"]:
                filename=data["filename"].split("/")[-1]
                annotations=data["annotations"]
                if annotations[0]["id"]=="bounding box 3D":
                    info_3d=annotations[0]
                    info_2d=annotations[1]
                else:
                    info_3d=annotations[1]
                    info_2d=annotations[0]
                    
                try:
                    object_info_dict=info_2d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    
                    object_types=[]
                    for item in sorted_data:
                        if item["label_id"] not in object_types:
                            object_types.append(item["label_id"])
                        else:
                            continue
                            
                    if len(object_types)==2: #2 object types
                        # use current logic of splitting sorted_data into list 1 and 2 based on label_id
                        first_instance_label_id = sorted_data[0]['label_id']
                        list1 = []
                        list2 = []
                        for item in sorted_data:
                            if item['label_id'] == first_instance_label_id:
                                list1.append(item)
                            else:
                                list2.append(item)
                        object1_info=[x["label_name"] for x in list1]
                        object2_info=[x["label_name"] for x in list2]
                        object1_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in list1]
                        object2_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in list2]

                        object_info_dict=info_3d["values"]
                        sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                        first_instance_label_id = sorted_data[0]['label_id']
                        list1 = []
                        list2 = []
                        for item in sorted_data:
                            if item['label_id'] == first_instance_label_id:
                                list1.append(item)
                            else:
                                list2.append(item)
                        object1_bb_3d=[x["size"] for x in list1]
                        object2_bb_3d=[x["size"] for x in list2]
                                            
                    else: #1 object type only
                        # set list 1 to be first object, the rest as object 2 \into list 2 
                        list1 = [sorted_data[0]]
                        list2 = [sorted_data[1:]]
                        object1_info=[x["label_name"] for x in list1]
                        object2_info=[x["label_name"] for x in list2]
                        object1_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in list1]
                        object2_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in list2]
                        
                        object_info_dict=info_3d["values"]
                        sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                        list1 = [sorted_data[0]]
                        list2 = [sorted_data[1:]]
                        object1_bb_3d=[x["size"] for x in list1]
                        object2_bb_3d=[x["size"] for x in list2]
                    
                except:
                    object1_info=[]
                    object2_info=[]
                    object1_bb_2d=[]
                    object2_bb_2d=[]
                    object1_bb_3d=[]
                    object2_bb_3d=[]
#                     print(f"error for {preposition_name}, {category}, {filename}, df index: {len(df)} ")

                new_row={
                    "preposition":preposition_name,
                    "category":category,
                    "image_file_name":filename,
                    "object_1_information":object1_info,
                    "object_2_information":object2_info,
                    "object_1_2d_bounding_boxes":object1_bb_2d,
                    "object_2_2d_bounding_boxes":object2_bb_2d,
                    "object_1_3d_bounding_boxes":object1_bb_3d,
                    "object_2_3d_bounding_boxes":object2_bb_3d,    
                }
                df.loc[len(df)] = new_row
        
        
print(preposition_name)
print(len(df))
df.tail()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:05<00:00,  1.85it/s]
# among
# 5000
#      preposition           category image_file_name  \
# 4995       among  vehicles vehicles      rgb_71.png
# 4996       among  vehicles vehicles      rgb_72.png
# 4997       among  vehicles vehicles      rgb_73.png
# 4998       among  vehicles vehicles      rgb_74.png
# 4999       among  vehicles vehicles      rgb_75.png
#
#                                    object_1_information  \
# 4995  [vehicles_motorcycle_model_normalized_21 Varia...
# 4996  [vehicles_car_model_normalized_7 Variant, vehi...
# 4997  [vehicles_motorcycle_model_normalized_9 Varian...
# 4998                                                 []
# 4999  [vehicles_car_model_normalized_20 Variant, veh...
#
#                                    object_2_information  \
# 4995  [vehicles_car_model_normalized_9 Variant, vehi...
# 4996  [vehicles_car_model_normalized_21 Variant, veh...
# 4997  [vehicles_motorcycle_model_normalized_21 Varia...
# 4998                                                 []
# 4999  [vehicles_motorcycle_model_normalized_26 Varia...
#
#                              object_1_2d_bounding_boxes  \
# 4995  [[136.0, 239.0, 2.0, 2.0], [120.0, 0.0, 50.0, ...
# 4996  [[414.0, 227.0, 9.0, 4.0], [333.0, 196.0, 50.0...
# 4997  [[316.0, 248.0, 2.0, 4.0], [330.0, 247.0, 61.0...
# 4998                                                 []
# 4999  [[338.0, 185.0, 8.0, 6.0], [257.0, 249.0, 87.0...
#
#                              object_2_2d_bounding_boxes  \
# 4995  [[133.0, 235.0, 8.0, 5.0], [262.0, 103.0, 81.0...
# 4996  [[414.0, 223.0, 9.0, 11.0], [212.0, 138.0, 118...
# 4997  [[316.0, 248.0, 1.0, 5.0], [167.0, 198.0, 32.0...
# 4998                                                 []
# 4999  [[228.0, 250.0, 36.0, 55.0], [273.0, 22.0, 77....
#
#                              object_1_3d_bounding_boxes  \
# 4995  [{'x': 0.129403, 'y': 0.211383, 'z': 0.4342489...
# 4996  [{'x': 0.3103416, 'y': 0.2079528, 'z': 0.70742...
# 4997  [{'x': 0.162418991, 'y': 0.165439516, 'z': 0.4...
# 4998                                                 []
# 4999  [{'x': 0.3314296, 'y': 0.212588772, 'z': 0.696...
#
#                              object_2_3d_bounding_boxes
# 4995  [{'x': 0.2968464, 'y': 0.219503224, 'z': 0.709...
# 4996  [{'x': 0.3095672, 'y': 0.325520784, 'z': 0.661...
# 4997  [{'x': 0.129403, 'y': 0.211383, 'z': 0.4342489...
# 4998                                                 []
# 4999  [{'x': 0.8176761, 'y': 0.91018796, 'z': 3.0831...

# %%
file=f"{preposition_name}.csv"
print(file)
df.to_csv(file,index=False)
# Out:
# among.csv

# %% [markdown]
# # archive og - dont edit

# %%
import os
import pandas as pd
from tqdm import tqdm

preposition_name="below"
root_folder_path="E:/SPUR NEURIPS"
preposition_folder_path=os.path.join(root_folder_path,preposition_name)

#create an empty df
columns=[
    "preposition",
    "category",
    "image_file_name",
    "object_1_information",
    "object_2_information",
    "object_1_2d_bounding_boxes",
    "object_2_2d_bounding_boxes",
    "object_1_3d_bounding_boxes",
    "object_2_3d_bounding_boxes",
]
 
df=pd.DataFrame(columns=columns)

categories=os.listdir(preposition_folder_path)
for category in tqdm(categories):
    category_folder_path=os.path.join(preposition_folder_path,category)
    category_folder_path_list=os.listdir(category_folder_path)
    category_folder_path_list=sorted(category_folder_path_list)
    dataset_folder_path=os.path.join(category_folder_path,category_folder_path_list[0])
    dataset_folder_path_list=os.listdir(dataset_folder_path)
    captures_list=[x for x in dataset_folder_path_list if x.startswith("captures")]
    for captures_json_file in captures_list:
        full_json_path=os.path.join(dataset_folder_path,captures_json_file)
        with open(full_json_path) as file:
            json_data = json.load(file)
            for data in json_data["captures"]:
                filename=data["filename"].split("/")[-1]
                annotations=data["annotations"]
                if annotations[0]["id"]=="bounding box 3D":
                    info_3d=annotations[0]
                    info_2d=annotations[1]
                else:
                    info_3d=annotations[1]
                    info_2d=annotations[0]
                    
                try:
                    object_info_dict=info_2d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    first_instance_label_id = sorted_data[0]['label_id']
                    list1 = []
                    list2 = []
                    for item in sorted_data:
                        if item['label_id'] == first_instance_label_id:
                            list1.append(item)
                        else:
                            list2.append(item)
                    object1_info=[x["label_name"] for x in list1]
                    object2_info=[x["label_name"] for x in list2]
                    object1_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in list1]
                    object2_bb_2d=[[x["x"],x["y"],x["width"],x["height"]] for x in list2]

                    object_info_dict=info_3d["values"]
                    sorted_data = sorted(object_info_dict, key=lambda x: x['instance_id'])
                    first_instance_label_id = sorted_data[0]['label_id']
                    list1 = []
                    list2 = []
                    for item in sorted_data:
                        if item['label_id'] == first_instance_label_id:
                            list1.append(item)
                        else:
                            list2.append(item)
                    object1_bb_3d=[[x["size"]] for x in list1]
                    object2_bb_3d=[[x["size"]] for x in list2]
                    
                except:
                    object1_info=[]
                    object2_info=[]
                    object1_bb_2d=[]
                    object2_bb_2d=[]
                    object1_bb_3d=[]
                    object2_bb_3d=[]
#                     print(f"error for {preposition_name}, {category}, {filename}, df index: {len(df)} ")

                new_row={
                    "preposition":preposition_name,
                    "category":category,
                    "image_file_name":filename,
                    "object_1_information":object1_info,
                    "object_2_information":object2_info,
                    "object_1_2d_bounding_boxes":object1_bb_2d,
                    "object_2_2d_bounding_boxes":object2_bb_2d,
                    "object_1_3d_bounding_boxes":object1_bb_3d,
                    "object_2_3d_bounding_boxes":object2_bb_3d,    
                }
                df.loc[len(df)] = new_row
        
        
print(preposition_name)
print(len(df))
df.tail()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:06<00:00,  2.16it/s]
# below
# 5000
#      preposition           category image_file_name  \
# 4995       below  vehicles vehicles      rgb_49.png
# 4996       below  vehicles vehicles      rgb_50.png
# 4997       below  vehicles vehicles      rgb_51.png
# 4998       below  vehicles vehicles      rgb_52.png
# 4999       below  vehicles vehicles      rgb_53.png
#
#                                    object_1_information  \
# 4995  [vehicles_motorcycle_model_normalized_26 Variant]
# 4996         [vehicles_bus_model_normalized_29 Variant]
# 4997  [vehicles_bus_model_normalized_29 Variant, veh...
# 4998   [vehicles_motorcycle_model_normalized_9 Variant]
# 4999          [vehicles_car_model_normalized_7 Variant]
#
#                                    object_2_information  \
# 4995  [vehicles_motorcycle_model_normalized_18 Variant]
# 4996         [vehicles_bus_model_normalized_22 Variant]
# 4997                                                 []
# 4998  [vehicles_motorcycle_model_normalized_21 Variant]
# 4999  [vehicles_motorcycle_model_normalized_26 Variant]
#
#                              object_1_2d_bounding_boxes  \
# 4995                       [[210.0, 365.0, 46.0, 89.0]]
# 4996                      [[41.0, 247.0, 431.0, 265.0]]
# 4997  [[123.0, 235.0, 389.0, 222.0], [218.0, 0.0, 29...
# 4998                       [[253.0, 278.0, 61.0, 46.0]]
# 4999                     [[155.0, 408.0, 123.0, 104.0]]
#
#           object_2_2d_bounding_boxes  \
# 4995    [[130.0, 73.0, 131.0, 96.0]]
# 4996  [[132.0, 108.0, 380.0, 127.0]]
# 4997                              []
# 4998     [[200.0, 52.0, 99.0, 88.0]]
# 4999   [[104.0, 189.0, 122.0, 55.0]]
#
#                              object_1_3d_bounding_boxes  \
# 4995  [[{'x': 3.68977356, 'y': 4.10723257, 'z': 13.9...
# 4996  [[{'x': 10.6660748, 'y': 11.8382, 'z': 40.5224...
# 4997  [[{'x': 10.7983313, 'y': 11.9849939, 'z': 41.0...
# 4998  [[{'x': 4.42329741, 'y': 4.50555849, 'z': 12.0...
# 4999  [[{'x': 8.064554, 'y': 5.40387154, 'z': 18.383...
#
#                              object_2_3d_bounding_boxes
# 4995  [[{'x': 2.55518985, 'y': 7.20174551, 'z': 12.1...
# 4996  [[{'x': 9.244875, 'y': 8.296465, 'z': 37.90234}]]
# 4997                                                 []
# 4998  [[{'x': 3.41124964, 'y': 5.57235861, 'z': 11.4...
# 4999  [[{'x': 3.185494, 'y': 3.54589963, 'z': 12.011...

# %%
file=f"{preposition_name}.csv"
print(file)
df.to_csv(file,index=False)
# Out:
# above.csv
